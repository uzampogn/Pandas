# %% [markdown]
# ## Settings

# %%
import datetime
import pandas as pd
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.float_format','{:.2f}'.format)

# %% [markdown]
# # Loading the data

# %%
df = pd.read_csv("/Users/quantic/Desktop/sp_dataset.csv")

# %% [markdown]
# # Data cleaning - Section 1
#
# 1. The data provided is dirty explain what steps should be taken to clean it, and provide example code that performs the cleaning operations you have specified.

# %% [markdown]
# ## Data exploration

# %%
# check the size of the dataset
print(f'The dataset contains   {df.shape[0]:,}   rows and   {df.shape[1]}   columns')
# Out:
# The dataset contains   36,112   rows and   26   columns

# %%
# check each columns names, count Non-null and data types
df.info()

# Note: A few columns have Null values which can be an indicator of tracking issues, 
#       namely: referral_url, geo columns (3x), page_title, link_click_target_url

# Note 2: Page_title & link_click_target_url null values is per design when a link_click event is recorded
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36112 entries, 0 to 36111
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   event_id               36112 non-null  object
#  1   web_page_id            36112 non-null  object
#  2   session_id             36112 non-null  object
#  3   session_index          36112 non-null  int64
#  4   user_cookie            36112 non-null  object
#  5   event_name             36112 non-null  object
#  6   page_title             34083 non-null  object
#  7   page_urlhost           36112 non-null  object
#  8   page_url               36112 non-null  object
#  9   referral_url           20205 non-null  object
#  10  dvce_created_tstamp    36112 non-null  object
#  11  geo_country            35048 non-null  object
#  12  geo_region             29157 non-null  object
#  13  geo_city               29096 non-null  object
#  14  geo_timezone           33291 non-null  object
#  15  pp_xoffset_min         28518 non-null  float64
#  16  pp_xoffset_max         28518 non-null  float64
#  17  pp_yoffset_min         28518 non-null  float64
#  18  pp_yoffset_max         28518 non-null  float64
#  19  doc_width              36112 non-null  int64
#  20  doc_height             36112 non-null  int64
#  21  useragent_family       36112 non-null  object
#  22  os_family              36112 non-null  object
#  23  device_family          36112 non-null  object
#  24  os_timezone            36111 non-null  object
#  25  link_click_target_url  2029 non-null   object
# dtypes: float64(4), int64(3), object(19)
# memory usage: 7.2+ MB

# %%
# Check the first 100 rows
#df.head(100)

# %%
# Check descriptive statistics of numeric fields
df.describe()
# Out:
#        session_index  pp_xoffset_min  pp_xoffset_max  pp_yoffset_min  \
# count       36112.00        28518.00        28518.00        28518.00
# mean           27.57            0.20            0.59         1738.84
# std           109.88            8.26           10.81         2336.05
# min             1.00         -245.00            0.00         -188.00
# 25%             1.00            0.00            0.00            0.00
# 50%             2.00            0.00            0.00          900.00
# 75%             7.00            0.00            0.00         2487.00
# max          1190.00          387.00          398.00        22674.00
#
#        pp_yoffset_max  doc_width  doc_height
# count        28518.00   36112.00    36112.00
# mean          2340.59    1443.27     6843.93
# std           2628.61     400.18     4373.77
# min              0.00     238.00      405.00
# 25%            423.00    1280.00     3012.00
# 50%           1500.00    1425.00     5862.00
# 75%           3280.00    1654.00    11498.00
# max          30494.00    3423.00   104642.00

# %%
# Check dates columns
print(f'Date ranges:  {min(pd.to_datetime(df.dvce_created_tstamp))} and {max(pd.to_datetime(df.dvce_created_tstamp))}')
# Out:
# Date ranges:  2020-02-10 04:11:00 and 2021-12-02 23:59:00

# %% [markdown]
# # List of Data Problems:
#
# 1. pp_xoffset_min contains negative numbers - it should be impossible.
# 2. pp_yoffset_min contains negative numbers - it should be impossible.
# 3. Drop irrelevant data in Referral_url e.g. 'XXX'
# 4. Geo_region contains data inconsistency with a mixture of string and integer. Additionally, data in geo_region doesn't match geo_country e.g. for geo_country = US, geo_region = CA
# 5. Data inconsistency with UTC values in os_timezone
# 6. Device_family needs further data transformation to be actionable
# 7. Investigate the data collection process to understand if missing values in referral_url, geo columns (3x) is intended. NB: For geo_columns, the os_timezone field has no missing values and can be used to create similar splits.

# %% [markdown]
# ### Solution 1 & 2:
# * pp_xoffset_min contains negative numbers
# * pp_yoffset_min contains negative numbers

# %%
# pp_xoffset_min replace negative numbers by 0 (inplace)
df.loc[df['pp_xoffset_min'] < 0, ['pp_xoffset_min']] = 0
# pp_yoffset_min replace negative numbers by 0 (inplace)
df.loc[df['pp_yoffset_min'] < 0, ['pp_yoffset_min']] = 0
# check if change was implemented
print(f"pp_xoffset_min :  \n{min(df['pp_xoffset_min'])}", end='\n\n')
print(f"pp_yoffset_min :  \n{min(df['pp_yoffset_min'])}")
# Out:
# pp_xoffset_min :
# 0.0
#
# pp_yoffset_min :
# 0.0

# %% [markdown]
# ### Solution 3:
# * Drop irrelevant data in Referral_url e.g. 'XXX'

# %%
# Data exploration
# df.loc[df['referral_url'] == 'XXX']

# %%
# SOLUTION: replace XXX by NaN
df['referral_url'] = df.loc[df['referral_url'] != 'XXX', ['referral_url']]
# check if change is implemented correctly
print(f"referral_url unique values :  \n\n{list(df['referral_url'].unique())}")
# Out:
# referral_url unique values :
#
# [nan, 'discourse.snowplowanalytics.com', 'www.google.com', 'snowplowanalytics.com', 'www.chess.com', 'yandex.ru', 'duckduckgo.com', 'github.com', 'www.aol.de']

# %%
# check if change is correctly implemented
df.iloc[72]
# Out:
# event_id                              5b562581-3ce5-470f-b62e-ea00b55ed326
# web_page_id                           4420373e-ada9-4521-bcc4-6b30cca2db47
# session_id               bc866191-22a4-4830-8f5a-9e38253fae4f          ...
# session_index                                                            1
# user_cookie                           bd393077-0949-422b-a21f-1e9b7593c6e1
# event_name                                                       page_ping
# page_title               Dealing with Hadoop's small files problem – Sn...
# page_urlhost                                         snowplowanalytics.com
# page_url                 https://snowplowanalytics.com/blog/2013/05/30/...
# referral_url                                                           NaN
# dvce_created_tstamp                                       11/02/2021 07:21
# geo_country                                                             US
# geo_region                                                              CA
# geo_city                                                       Los Angeles
# geo_timezone                                           America/Los_Angeles
# pp_xoffset_min                                                        0.00
# pp_xoffset_max                                                        0.00
# pp_yoffset_min                                                      680.00
# pp_yoffset_max                                                      680.00
# doc_width                                                             1440
# doc_height                                                            5862
# useragent_family                                                    Chrome
# os_family                                                         Mac OS X
# device_family                                                        Other
# os_timezone                                            America/Los_Angeles
# link_click_target_url                                                  NaN
# Name: 72, dtype: object

# %% [markdown]
# ### Solution 4:
# * Geo_region contains data inconsistency with a mixture of string and integer. Additionally, data in geo_region doesn't match geo_country e.g. for geo_country = US, geo_region = CA

# %%
# Data exploration: Unique values in geo_region 
print(list(df.geo_region.unique()))

# Note: 
# Data inconsistency with a mixture of string and integer. 
# Additionally, data in geo_region doesn't match geo_country e.g. for geo_country = US, geo_region = CA
# Out:
# ['CA', '7', '2', '16', '8', '0', nan, 'NY', 'TX', 'VA', '39', '12', 'NM', '10', '23', 'WA', 'NJ', 'J8', '56', '60', 'A8', '5', '4', '72', '36', 'H1', '19', 'H9', '20', '35', '26', '22', '58', 'K5', '25', '6', '17', 'MD', 'CO', 'FL', '42', 'MA', 'C3', 'IN', 'NH', '48', '11', 'IL', 'GA', 'NC', 'D9', '78', 'MN', 'OH', '9', 'AZ', 'SC', '18', 'J1', '86', '13', 'KY', '83', '77', '47', 'B8', 'KS', '33', 'B5', '44', '27', '30', '14', '3', 'H7', '75', 'E7', '55', 'B7', 'CT', 'I4', 'K2', 'B9', 'ON', 'BC', '29', 'MB', 'PA', 'OR', 'OK', 'IA', '1', '40', '84', '32', 'I7', 'G1', 'P1', 'B4', 'MO', 'DC', '21', 'WI', 'HI', 'E2', 'D7', '66', 'AB', 'I2', 'TN', '62', 'X5', 'F8', 'A5', 'ME', 'RI', 'UT', '34', '37', '53', 'G4', 'M2', '91', 'QC', 'J7', 'M5', '73', 'NV', 'MI', 'A7', 'A2', '28', 'F1', 'DE', '65', '52', 'B3', 'G5', 'P5', 'D8', 'P2', 'G2', '24', '90', 'F3', 'L1', 'NB', 'C5', '15', 'I8', 'I1', 'H5', 'P3', 'A9', '82', 'A6', 'K7', 'D4', '81', 'M3', 'ID', 'F2', 'L5', 'P9', 'N5', 'K8', '41', 'B2', '45', '87', '71', 'I6', '51', 'Q5', 'G8', 'LA', 'A1', 'D2', 'F4', '57', '31', 'C1', 'E3']

# %%
# SOLUTION: Use geo_timezone to repopulate correctly geo_region
df['geo_region'] = df['geo_timezone'].str.split('/').str[0]

# %%
# Check if change is correctly implemented
print(list(df.geo_region.unique()), end='\n')
# Out:
# ['America', 'Australia', 'Asia', nan, 'Europe', 'Africa', 'Pacific', 'Atlantic', 'Indian']

# %% [markdown]
# ### Solution 5:
# * Data inconsistency with UTC values in os_timezone

# %%
# Data exploration

# Note: 
# US & MA are not UTC time
df.loc[(df.os_timezone == 'UTC'), ['geo_timezone', 'geo_country', 'geo_timezone']].drop_duplicates()
# Out:
#               geo_timezone geo_country         geo_timezone
# 4      America/Los_Angeles          US  America/Los_Angeles
# 952          Europe/London          GB        Europe/London
# 6887    Atlantic/Reykjavik          IS   Atlantic/Reykjavik
# 9972      America/New_York          US     America/New_York
# 10554    Africa/Casablanca          MA    Africa/Casablanca
# 17586       America/Denver          US       America/Denver
# 27436         Africa/Accra          GH         Africa/Accra

# %%
# SOLUTION: overwrite UTC with proper geo_timezone
df.loc[(df.os_timezone == 'UTC') & (df.geo_country == 'US'), ['os_timezone']] = df.geo_timezone
# check if change is correctly implemented
df.loc[(df.os_timezone == 'UTC') & (df.geo_country == 'US'), ['os_timezone']].count()
# Out:
# os_timezone    0
# dtype: int64

# %%
# SOLUTION: overwrite UTC with proper geo_timezone
df.loc[(df.os_timezone == 'UTC') & (df.geo_country == 'MA'), ['os_timezone']] = df.geo_timezone
# check if change is correctly implemented
df.loc[(df.os_timezone == 'UTC') & (df.geo_country == 'MA'), ['os_timezone']].count()
# Out:
# os_timezone    0
# dtype: int64

# %% [markdown]
# ### Solution 6:
#
# Device_family needs further data transformation to be actionable. The field cannot be used currently. I advise to create another column grouping each value according to their brand e.g. SM-G930S should be classified as Samsung
#
# NB: This is a very manual process as I would need to google each entry in the list below. In the interest of time and because I won't use this field in the next section of this analysis, I will skip the implementation of the solution proposed here.

# %%
df.device_family.value_counts()
# Out:
# Other                      33337
# iPhone                       748
# Spider                       500
# iPad                         196
# SAMSUNG-SM-G930A             136
# Nexus 5X                     127
# Nexus 6P                      79
# MI 5                          75
# SM-G930F                      72
# SM-G900F                      63
# Moto G (4)                    61
# MotoG3                        57
# XT1032                        37
# XT1254                        36
# Redmi Note 3                  35
# XT1706                        34
# SAMSUNG SM-J500F              30
# SM-J700F                      30
# XT1068                        23
# SM-N750                       21
# A0001                         21
# ASUS_Z017D                    20
# SM-G920T                      20
# Redmi Note 4                  19
# LG-H812                       18
# SM-G920F                      18
# HUAWEI ALE-L04                17
# SM-G930S                      16
# SM-G900T                      15
# SM-G935F                      14
# SM-G930T                      13
# Kindle Fire                   13
# SAMSUNG SM-G900F              13
# ONEPLUS A3003                 12
# SAMSUNG SM-G920F              12
# XT1021                        12
# SAMSUNG SM-G935F               9
# HTC Desire                     9
# SAMSUNG-SM-G920A               9
# SAMSUNG SM-N910V 4G            8
# Pixel XL                       8
# SAMSUNG SM-G900FD              7
# LG-H735                        6
# ZUK Z1                         6
# SM-P550                        6
# HUAWEI VNS-L21                 6
# HTC One                        6
# Nexus 5                        6
# D5803                          6
# YOGA Tablet 2 Pro-1380F        5
# ASUS_T00J                      5
# Redmi 3S                       5
# PO10317TAQ-70242MK3            4
# MI MAX                         4
# BTV-DL09                       3
# GT-I9505                       3
# STV100-1                       3
# HTC One M                      3
# LG-D802                        3
# SAMSUNG SM-G935T               3
# SM-N920V                       3
# ASUS_Z010D                     3
# Nexus 7                        2
# SM-G610F                       2
# HUAWEI VNS-L31                 2
# E6883                          2
# SAMSUNG SM-N9005               2
# ONE E1001                      2
# XT1563                         2
# GT-N7100                       1
# SAMSUNG SM-G530T1              1
# itel it1505                    1
# GT-I9060                       1
# SM-J320FN                      1
# Nokia 203                      1
# Mi-4c                          1
# F1f                            1
# MX5                            1
# Name: device_family, dtype: int64

# %% [markdown]
# # Final Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36112 entries, 0 to 36111
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   event_id               36112 non-null  object
#  1   web_page_id            36112 non-null  object
#  2   session_id             36112 non-null  object
#  3   session_index          36112 non-null  int64
#  4   user_cookie            36112 non-null  object
#  5   event_name             36112 non-null  object
#  6   page_title             34083 non-null  object
#  7   page_urlhost           36112 non-null  object
#  8   page_url               36112 non-null  object
#  9   referral_url           19491 non-null  object
#  10  dvce_created_tstamp    36112 non-null  object
#  11  geo_country            35048 non-null  object
#  12  geo_region             33291 non-null  object
#  13  geo_city               29096 non-null  object
#  14  geo_timezone           33291 non-null  object
#  15  pp_xoffset_min         28518 non-null  float64
#  16  pp_xoffset_max         28518 non-null  float64
#  17  pp_yoffset_min         28518 non-null  float64
#  18  pp_yoffset_max         28518 non-null  float64
#  19  doc_width              36112 non-null  int64
#  20  doc_height             36112 non-null  int64
#  21  useragent_family       36112 non-null  object
#  22  os_family              36112 non-null  object
#  23  device_family          36112 non-null  object
#  24  os_timezone            36111 non-null  object
#  25  link_click_target_url  2029 non-null   object
# dtypes: float64(4), int64(3), object(19)
# memory usage: 7.2+ MB

# %% [markdown]
# # Data analysis & modelling - Section 2
#
# 2. Use the clean dataset to calculate the following metrics (share any code generated when calculating these metrics):
#    * a. Session bounce rate
#    * b. Average time engaged on each page view
#    * c. Average scroll depth on each page view
#    * d. What % of users start their journey on page_urlhost ='snowplowanalytics.com' before navigating to page_urlhost ='discourse.snowplowanalytics.com'

# %% [markdown]
# ## Compute:
# * a. Session Bounce Rate

# %%
# DEFINTION of bounce rate: 
# percentage of visitors to a particular website who navigate away from the site after viewing only one page

# Count page_views per session
df_session_count = (df.loc[
                          df['event_name']=='page_view'
                          ,['session_id','event_name']
                          ].groupby(['session_id'])
                           .count()
                   )
# Session bounce rate = sessions with 1 page view / total sessions count
session_bounce_rate = len(df_session_count.loc[df_session_count['event_name'] == 1])/len(df_session_count)
# print results
print(f'Session bounce rate is {session_bounce_rate:.2%}')
# Out:
# Session bounce rate is 74.27%

# %% [markdown]
# ## Compute:
# * b. Average time engaged on each page view

# %%
# Filter dataset on page_view & page_ping + select only relevant columns
df_time = (df.loc[
                 (df['event_name']=='page_view') | (df['event_name']=='page_ping')
                 ,['session_id','page_title','dvce_created_tstamp']
                 ]
          )
# convert to datetime
df_time['dvce_created_tstamp'] = pd.to_datetime(df_time['dvce_created_tstamp'])
# add min & max columns
df_time['max'] = df_time.groupby(['session_id','page_title'])['dvce_created_tstamp'].transform('max')
df_time['min'] = df_time.groupby(['session_id','page_title'])['dvce_created_tstamp'].transform('min')
# drop irrelevant column
df_time.drop(['dvce_created_tstamp'], axis=1, inplace=True)
# add time on site column
df_time['time_on_site'] = df_time.apply(
                                        lambda row: row['max'] - row['min'] 
                                        if row['max'].date() == row['min'].date() 
                                        else pd.to_timedelta(0)
                                        , axis=1
                                        )
# convert timedelta to seconds
df_time['time_on_site'] = df_time['time_on_site'].apply(lambda row: row.total_seconds())
# convert seconds to minutes
df_time['time_on_site'] = df_time.apply(lambda row: row['time_on_site']/60, axis=1)
# compute the average time on site per page title
avg_time= df_time.groupby(['page_title']).mean().sort_values(by='time_on_site',ascending=False)
# convert float to percentage for file export
df_time['time_on_site'] = df_time['time_on_site'].apply(lambda x: format(x, '.2'))

# %%
# Average time on each page in minutes
avg_time.head(10)
# Out:
#                                                     time_on_site
# page_title
# User id and session id in AMP page - Tracking S...        856.00
# How to store kinesis enriched stream to redshif...        431.00
# Snowplow Bounce Rate - Tableau - For data model...        289.22
# Batch v real time enrichment - Discourse – Snow...        223.85
# Why is the Redshift table definition for a sche...        189.00
# Enriched event stream into Redshift using Stora...        182.08
# How to store kinesis enriched stream to redshif...        173.00
# Error using StorageLoader to load data into Red...        136.04
# Debugging bad rows in Spark and Zeppelin [tutor...        102.85
# Error tracking in the Javascript Tracker 2.7.0 ...         83.48

# %%
# check shape
avg_time.shape
# Out:
# (717, 1)

# %%
# Data consistency check: unique number of page_titles in original dataset. 717 + 1 (NaN)
len(pd.unique(df['page_title']))
# Out:
# 718

# %%
# Export full table with 717 unique pages
avg_time.to_csv("/Users/quantic/Desktop//Snowplow - Use Case/Task Two - 2a - avg time per page.csv")

# %% [markdown]
# ## Compute:
# * c. Average time scroll depth on each page view

# %%
# Filter dataset on page_view & page_ping + select only relevant columns
df_scroll = df.loc[
                    (df['event_name']=='page_view') | (df['event_name']=='page_ping')
                    ,['page_title','pp_yoffset_max','doc_height']
                  ]
# fill na
df_scroll['pp_yoffset_max'] = df_scroll['pp_yoffset_max'].fillna(0)
# add scroll depth
df_scroll['scroll_depth'] = df_scroll.apply(
                                            lambda row: row['pp_yoffset_max']/row['doc_height'] 
                                            if row['pp_yoffset_max'] != 0 
                                            else 0
                                            , axis=1
                                            )
# drop irrelevant columns
df_scroll.drop(['pp_yoffset_max','doc_height'],inplace=True, axis=1)
# set max scroll_depth to 100%
df_scroll.loc[df_scroll['scroll_depth'] > 1,['scroll_depth']] = 1
# avg scroll depth per page 
avg_scroll = df_scroll.groupby(['page_title']).mean().sort_values(by='scroll_depth',ascending=False)
# convert float to percentage 
avg_scroll['scroll_depth'] = avg_scroll['scroll_depth'].apply(lambda x: format(x, '.2%'))

# %%
# check if we have the same number of page_title 
# than in unique number of page_titles in original dataset. 717 + 1 (NaN)
avg_scroll.shape
# Out:
# (717, 1)

# %%
avg_scroll.to_csv("/Users/quantic/Desktop/Snowplow - Use Case/Task Two - 2b - avg scroll depth per page.csv")
avg_scroll.head(10)
# Out:
#                                                    scroll_depth
# page_title
# EMR jobflow failing on Hadoop Enrich step after...      100.00%
# Data collection: the essential but unloved, fou...      100.00%
# Latest For engineers topics - Discourse – Snowplow       80.67%
# User id and session id in AMP page - For engine...       65.86%
# Stream Collector process dead randomly - For en...       65.12%
# Error while uploading snowplow logs to s3 - For...       63.04%
# Processing logs for a specific time period - Fo...       62.35%
# Vacuums in Redshift and new Redshift Enhancemen...       62.30%
# Latest For data modelers & consumers topics - D...       55.94%
# 'Elasticity Scalding Step: Shred Enriched Event...       54.12%

# %% [markdown]
# ## Compute:
# * d. What % of users start their journey on page_urlhost ='snowplowanalytics.com' before navigating to page_urlhost ='discourse.snowplowanalytics.com'

# %% [markdown]
# ### Option 1: using referral_url
# Assumption: referral_url records the previous page visited

# %%
# Data exploration for numerator: users starting on Snowplowanalytics and continuing to Discourse
(df.loc[
        (df['event_name']=='page_view') & (df['page_urlhost']=='discourse.snowplowanalytics.com')
       ].referral_url
        .fillna('NaN')
        .value_counts()
)
# Out:
# www.google.com                     1043
# NaN                                 348
# discourse.snowplowanalytics.com     121
# snowplowanalytics.com                20
# www.chess.com                         3
# yandex.ru                             3
# duckduckgo.com                        3
# github.com                            2
# Name: referral_url, dtype: int64

# %%
# Filtering on page_urlhost & referral_url to get distinct users starting on Snowplowanalytics 
# and continuing to Discourse

# Note: I assume that referral_url records the previous page visited
discourse_page = (df.loc[
                         (df['event_name']=='page_view') 
                         & (df['page_urlhost']=='discourse.snowplowanalytics.com') 
                         & (df['referral_url']=='snowplowanalytics.com')
                         ]
                 )
discourse_page = len(discourse_page.groupby(['session_id'])['session_id'])

# %%
# Data exploration for denominator: users starting on Snowplowanalytics
(df.loc[
        (df['event_name']=='page_view') 
        & (df['page_urlhost']=='snowplowanalytics.com')
       ].referral_url
        .fillna('NaN')
        .value_counts()
)
# Note: I assume that referral_url NaN means no previous page_view. 
#       Thus I'll consider all users except from snowplowanalytics and discourse.
# Out:
# NaN                                1775
# snowplowanalytics.com              1499
# www.google.com                      677
# yandex.ru                            13
# www.chess.com                         9
# github.com                            7
# duckduckgo.com                        6
# www.aol.de                            4
# discourse.snowplowanalytics.com       2
# Name: referral_url, dtype: int64

# %%
# Filering on page_urlhost & referral_url to get distinct users starting on Snowplowanalytics
snowplow_page = (df.loc[
                        (df['event_name']=='page_view') 
                        & (df['page_urlhost']=='snowplowanalytics.com') 
                        & (df['referral_url']!='snowplowanalytics.com') 
                        & (df['referral_url']!='discourse.snowplowanalytics.com')
                        ]
                )
snowplow_page = len(snowplow_page.groupby(['session_id'])['session_id'])

# %%
percent_users = discourse_page/snowplow_page
print(f'Distinct users starting on Snowplowanalytics: {snowplow_page}')
print(f'Distinct users starting on Snowplowanalytics and continuing to Discourse: {discourse_page}')
print(f'Percentage of users is: {percent_users:.2%}')
# Out:
# Distinct users starting on Snowplowanalytics: 2004
# Distinct users starting on Snowplowanalytics and continuing to Discourse: 18
# Percentage of users is: 0.90%

# %% [markdown]
# ### Option 2: ranking page_view events per session
# Assumption:

# %%
# Filter data on page view + retrieving relevant columns
df_temp = df.loc[(df['event_name']=='page_view'), ['session_id','page_urlhost','dvce_created_tstamp','referral_url']].reset_index(drop=True)
# converting dvce_created_tstamp to timestap
df_temp['dvce_created_tstamp'] = pd.to_datetime(df_temp['dvce_created_tstamp'])
# sorting values by session_id & timestamp
df_temp.sort_values(by=['session_id','dvce_created_tstamp'],ascending=True,inplace=True)
# ranking page_views for each session by their time appearance
df_temp['rank'] = df_temp.groupby(['session_id'])['dvce_created_tstamp'].rank(method='first')

# %%
# Create a table with all users starting with snowplowanalytics.com
df_table1 = df_temp.loc[(df_temp['page_urlhost']=='snowplowanalytics.com')&(df_temp['rank']==1)&(df_temp['referral_url']!='snowplowanalytics.com')]
# count distinct on session_id
denominator = len(df_table1.groupby(['session_id'])['session_id'])
len(df_table1.groupby(['session_id'])['session_id'])
# Out:
# 1868

# %%
#df_table1.referral_url.value_counts()
df_table1.loc[df_table1['referral_url']=='snowplowanalytics.com']
# Out:
#                                              session_id  \
# 2776  009847f5-0018-4ccf-8098-363980188f8e          ...
# 4052  00c0baf0-0020-44e6-8000-82f100605a70          ...
# 1372  07f53503-a5fa-485e-8b73-0d06f325dd34          ...
# 3377  080453e8-f540-4221-8f70-124f264fd536          ...
# 4854  0882d350-8bcf-4d5b-9da7-56bac6ef77b6          ...
# 2639  090786d4-33e8-4068-83de-9e2db4e2947a          ...
# 1749  09a8f99c-35b5-4a41-9891-c3ad833f0364          ...
# 712   0b601f39-2835-4c0c-a3c7-5139a32a1507          ...
# 3194  0bf709f3-03c8-4721-87de-5fb89b632ca3          ...
# 2213  0ccf115a-a3b8-4287-aac9-0cf9bc478fad          ...
# 1871  0eaf800c-0e77-40f5-8676-f2ea8f630609          ...
# 4302  0fda323a-7071-496b-b35e-6a4cae55cb22          ...
# 4767  106e196c-f1db-4dd0-a31c-b3cc39edc216          ...
# 5281  126f14a6-fbec-4da7-a0ea-b080afc32a04          ...
# 4945  12772d9f-7381-4690-81f4-989210937ee0          ...
# 4426  1330fc26-381a-4c80-ac27-4a470865ab38          ...
# 2749  150bbaa7-9be5-47cb-969e-8c018aa19fe1          ...
# 1364  166fa4cc-dafa-46e0-b937-b0a570438a93          ...
# 4260  170fd008-f192-4076-8761-7812a6ecface          ...
# 1101  17aaef00-5c63-4a37-a20c-e20df680e833          ...
# 34    188c7594-fb48-409a-be10-8c2d79e60de8          ...
# 2135  18ec732a-c9ff-4dec-9586-893c04d5a7e9          ...
# 60    1a4c85db-99d3-4d3a-a4b0-95b238784501          ...
# 2436  1aa0f6bb-b92f-4f35-b2c7-1115b669a14c          ...
# 635   1aaf192f-bd20-4fc9-ad24-6b24ecd2bc13          ...
# 2049  1b8a5dfe-a0a5-48b3-a760-1dcef50e9848          ...
# 4707  1cb8fc57-b8f2-4e09-b0b7-740bbfc58d57          ...
# 2398  1e9cdd5d-4aaa-454e-ad5c-61f28c19a5ea          ...
# 1184  205bf57a-2b86-4750-b14c-93ae5a71057e          ...
# 3132  2097b9fb-7dc8-436e-9d57-25cda2ceec56          ...
# 4877  20f86a4c-7de0-4b88-ac8e-39400d769255          ...
# 106   20fd829a-96d8-4caf-bd3b-2727a07adfc7          ...
# 5276  21246f02-b8b4-4440-bcb2-396ebf94d2e3          ...
# 3062  21383247-49e0-421a-a660-1d8fa3651a0c          ...
# 772   2183d243-a8cd-4f12-bcef-50568d70d7bd          ...
# 2706  21a9ddef-f509-4bec-9d8e-c6ca0760df23          ...
# 3585  22f5ed02-1b55-41d4-9989-5219dfb07dd1          ...
# 4059  245b45d9-0ef4-4e62-8a30-d3fafe6b969b          ...
# 5319  245e179c-1f26-4985-a97c-e05cdf71d20b          ...
# 2035  25b27af6-b87c-46d1-9cac-4d89e9d4b083          ...
# 2311  25fdf2c5-47da-4680-9428-ba66e7f64896          ...
# 3999  264ca0f1-8e19-40ce-af63-f8ec1472a52d          ...
# 5449  265afca9-f284-446e-aa3d-02b4f53a8d36          ...
# 3402  27776056-a858-40c4-bda2-3b74b359ed5e          ...
# 630   28997ebd-6385-45e8-a8af-0d9022648e56          ...
# 1326  28b5435c-9c44-49a5-8966-8a381df27012          ...
# 1703  29260581-9d2f-4103-9522-3b6560cb2d4c          ...
# 2143  2d88930a-f4b4-4297-9ea1-75b26cb8fb2a          ...
# 1381  2f94f3c8-8727-40e3-850a-31b89e018005          ...
# 3101  2fa2f5bb-6000-4849-9712-30bbdf971a70          ...
# 507   30885598-e8ae-4225-a8fc-9762df72556a          ...
# 1531  30c2a44a-5784-4396-b1c3-5690641180d1          ...
# 2916  30cdb27d-1b41-4d56-9bc0-7309700bdc0f          ...
# 1329  31679612-1ebe-42dc-a66e-9ff4faa93fac          ...
# 4100  32ca046e-1484-47dc-a0e4-ed578a0daa9c          ...
# 3694  34451af4-23e0-4b92-b7d3-5919e72d8128          ...
# 1697  348da440-261c-4036-845f-b4d73f537ee9          ...
# 3665  353403a1-c925-497a-8de3-d7b1c13ead27          ...
# 267   35710b64-85c2-46cf-94a2-56915abefca5          ...
# 4456  3684a5c7-2202-498b-a87e-389cddd1fa7a          ...
# 2294  376463dd-57c6-4e89-8466-1811a8e52edc          ...
# 1158  37e7b703-4f0e-4641-8114-75be48b60e05          ...
# 4522  3b0be235-c251-4036-8642-eb23f27fd5c0          ...
# 1306  3b5708ee-65da-4d8c-ae08-9b6a28e01d6a          ...
# 325   3b912aaa-3bde-4038-ad4b-63b75231f9b8          ...
# 1083  3bdea110-c70d-4c49-ae97-6a7151e82194          ...
# 1604  3e3cf3ce-de17-4afa-80c1-ddfd756d7ff0          ...
# 1209  3efe5b5a-4f13-47c3-9509-604063ccddb3          ...
# 4980  3fb0502b-8915-4413-badb-03c86470618b          ...
# 3960  3ffc1b1d-e32f-41c8-a454-bf6f47212e2e          ...
# 4986  4185e591-9e6a-48f7-976a-273ec83cd180          ...
# 1563  41d714df-05de-4ac7-a948-441ae0b68c3f          ...
# 3536  41e24feb-c541-4f65-af88-9e6eea3022f3          ...
# 2225  443c11c5-8340-49e4-b5dc-7ff63776c298          ...
# 3116  44731e9f-8174-4ea6-a0e0-137dd2a34ac4          ...
# 530   45466975-1158-4c23-8bb0-eae0cd8696c0          ...
# 1321  45573698-6bbe-4073-9b5d-67de79288300          ...
# 3777  456d99cf-c3df-477e-a760-0dda7dbbe087          ...
# 837   45bb3c81-fd38-436e-a3ab-5e9c1a6545a1          ...
# 1206  45d50428-c785-48d3-8dd2-896ab80d5f84          ...
# 321   4620349c-638e-41cd-92ea-183479eefc1f          ...
# 156   47902d57-a14f-463a-986a-4cc71b954d5a          ...
# 1412  484707c7-ca7b-4dc0-8964-b659492c4907          ...
# 1375  49b80bd2-d40c-45f3-8c66-8abf50f7b28e          ...
# 1396  49ecb2d6-9709-4064-a7e9-67e881f9f5eb          ...
# 852   4ba26ca6-3aac-4e83-9586-cfa7b50a2e23          ...
# 1610  4c112840-c19b-45e0-be83-5a7ba88500f8          ...
# 1841  4c3f8391-1952-40ae-89e7-f2b5eeab32cc          ...
# 569   4cdca8cd-1dfb-4b9b-a824-2748d1743870          ...
# 886   4d76cebf-7214-4e32-b025-bd1f4c046ab1          ...
# 486   4d7e0089-2048-4579-bfad-01f49dae8dff          ...
# 1226  4f0ca869-08da-41fc-ad4c-45d9eb518998          ...
# 662   50d4f713-6405-41c7-9965-6d49f4808a74          ...
# 341   532979fe-d868-4381-a8f4-40e81af9dc6a          ...
# 865   53c37c42-f2aa-4ddc-89ef-e69d43e7ab92          ...
# 1917  54d07318-1619-44f5-9ce4-3c18ec4ccf25          ...
# 2459  55682395-f250-4edf-ad23-acbce5ff0f89          ...
# 4720  571a2729-120e-4f09-a5ae-cbacb8eb1d88          ...
# 939   575461ec-ab93-4ed2-9388-9ae56ea83380          ...
# 3991  57a64f19-c6e2-4f13-9934-fa5d9173c710          ...
# 2204  57bc6ddf-16ee-4d1f-ae00-a4d43967b939          ...
# 468   5b72581c-0233-4f6c-9c24-cfb5b1a62105          ...
# 225   5d51b5de-ae3b-4772-a74d-3ca4a6b81729          ...
# 485   5fe74479-f020-46c9-9648-a754a3de8bf8          ...
# 1709  6041e6b8-bad0-430b-acc1-421012a89d1c          ...
# 2132  615506fb-82cc-4d73-8e06-0b824fd69911          ...
# 374   62201f2b-cec0-4140-b677-4ab553ff8b50          ...
# 1698  65b300f3-ead3-4c07-88dd-031d0d03265f          ...
# 4972  65ca6ba8-a96f-493f-a843-72b34a6d4007          ...
# 3162  678da6c2-3008-477d-870b-19f1cb95cf05          ...
# 3904  6816f8a0-310a-445b-a4f4-0ab36d6721a0          ...
# 730   69511ed3-1f53-4524-ab9e-34c8d56e9a2d          ...
# 4965  6a37a182-4b89-4996-966c-4b901b194e68          ...
# 680   6a639f08-c4f7-4ac3-a263-e5fe29189898          ...
# 2263  6b547cdc-a94a-4237-9a2e-65c06f07ee59          ...
# 893   6b898306-a546-4952-a324-ab6d4de572b6          ...
# 781   6d5f5cc8-2b61-4590-a65b-56a48c15a378          ...
# 205   6d812c4e-adce-4cec-a9b8-944aa0387db7          ...
# 2388  6fbc4e3e-752a-4fb6-90e7-0d93b1cf679d          ...
# 2478  70bff98f-9e41-4e5f-8f69-8a458ffed0d1          ...
# 973   70cffd4e-00d3-45d7-8038-25258038e977          ...
# 622   70e73eaf-516d-4094-9c3e-0f835d68e2ab          ...
# 912   712578bc-e315-41d6-8534-2c82893ce262          ...
# 1047  719ff6cc-6e56-4650-bf0b-04db36c37069          ...
# 3620  72e4716a-8898-48ef-a529-22472eed11a1          ...
# 1304  75123a1e-452d-4892-9f6d-fa1a180250f2          ...
# 2437  75c93f11-7c16-4084-bfe7-e7018f2049a5          ...
# 4213  7863b875-f379-4968-8679-edf6afb3b23a          ...
# 2361  7b410085-a8aa-43e9-b57e-584eaeaeb812          ...
# 2669  7bff09ae-2dc7-467e-a78b-7680fc008bcc          ...
# 2333  7cbe71e7-dbd0-45c1-99d6-33e75083e851          ...
# 2103  7ece01d6-c143-478b-8e76-bc83f4ea739c          ...
# 230   7f534e0f-9b7c-4a32-8c46-80027d42b7f9          ...
# 1073  7f9a2284-3b8e-44bb-b7d6-266b90f0e397          ...
# 754   7f9e9b30-0200-4b7b-ba88-9c0c498b2a41          ...
# 3593  7feb5f92-79bf-4526-90c8-fe7d315bf129          ...
# 4133  82082d30-f136-44ff-9d4a-55ced7c55b82          ...
# 1930  831347c7-7e21-4edf-8d44-25430e5bd88a          ...
# 21    8319a58d-029e-4188-b2eb-0ff7e8895c92          ...
# 1641  83e88e43-bacf-4720-80fa-b3b51510be2c          ...
# 1866  856bfa9a-89e2-4003-9229-20b17087c8b0          ...
# 766   856fdbf5-2744-47a8-b350-0d2f7d635518          ...
# 49    85c8f0f6-168b-4864-910a-0ba63b309bf2          ...
# 1325  8626f9b4-a9c2-4793-b65d-06a2e98e072d          ...
# 1651  87b26836-2844-4a25-9bc0-3bf973870dd3          ...
# 1084  87e30ebc-2a17-42d9-b2ae-885a7b5b7dea          ...
# 1193  87f05264-ade9-4404-912c-589ec5823f50          ...
# 1852  895139ab-9413-47c1-858c-a2886e95a47b          ...
# 5107  8a546186-4d81-488b-ad39-4548d248e058          ...
# 452   8a72cd71-eb8f-4fb2-9b60-b653c970396d          ...
# 5512  8a98148e-69ca-4e60-8f34-811d79654ce7          ...
# 295   8bc9fea2-37b9-4e8a-a517-5cd731968577          ...
# 1516  8d49e6a3-7eae-4b92-960c-b9d770c459ba          ...
# 3031  8f97bd3d-ccff-4bf7-8e79-d17220e903ad          ...
# 1780  90146e8d-faba-4d90-be91-ad9f563bc53b          ...
# 2730  90659f50-e7c2-49a7-a2ad-c714ab9b9f0d          ...
# 2482  909409c1-c600-4e1c-a3a2-4b3849571e87          ...
# 1689  90f4094a-ff26-4260-b15e-7350c0b5fe67          ...
# 2990  910171f8-b670-4644-a242-e94e14301584          ...
# 1900  919cfa8c-b018-4f39-9786-c962aff54a25          ...
# 810   91d8c292-48ec-406c-9150-54ea619dc91f          ...
# 457   920e0729-a758-424f-9ca7-c695e80afeaf          ...
# 2773  927822c9-272d-48e7-856a-a3ba56813d21          ...
# 1696  92f8fa17-6c07-4777-8752-f39b285929d2          ...
# 560   93359ead-bc9b-4590-84e1-d1daf34521a5          ...
# 992   93749d66-fc01-4247-9b90-9c0f78f6dbdd          ...
# 2893  93f5359c-19ef-44e0-95c0-b3d335940227          ...
# 736   94cc517e-a20d-4e6b-9861-adffd8367d98          ...
# 5546  95533d8b-60ac-4d40-9916-5f0230795334          ...
# 3811  96cc08c9-d6f0-4408-8a30-19b75c952fc1          ...
# 770   98517e56-fa33-4f6a-a5bd-f8581467ed2c          ...
# 1330  98998059-3d83-41da-92e5-d46ebe4319e6          ...
# 101   9a9c9f02-640b-40c4-b692-77b716baa2d7          ...
# 74    9aa16f2f-c29c-4ef4-896d-ae3b5bb4dbe4          ...
# 3207  9ae9e8d3-ae83-4b52-89a7-77f290528719          ...
# 785   9afa7923-1527-488e-8f2a-ad8e33cc2810          ...
# 2630  9e392633-dd7f-4b89-acb6-d112b13c9eff          ...
# 2448  a0e6f865-ef9e-468b-bec8-550ff89d5641          ...
# 3374  a0efc5a8-4fef-4748-81bc-03182308e1d2          ...
# 3166  a0ffd115-55ac-438d-a439-de5770f87ac9          ...
# 3775  a1b8338e-daef-4aec-b46b-c7df87d3f5c8          ...
# 3660  a33875f6-5218-48aa-b8c8-8b9cad3f1944          ...
# 346   a4646ca8-c620-45b8-b32d-f38e1781dd97          ...
# 4578  a5050678-5931-4e24-b53a-083028bdfce1          ...
# 4119  a71be390-ab41-4348-ab7b-c9c11bfd0aa7          ...
# 1324  a7e68a02-6914-444e-849d-9e05c19a7deb          ...
# 4340  a9155787-2bde-45e0-bf9e-bb56ce10fddb          ...
# 1389  a94898d4-0caf-458f-b5cd-b419ac0c787a          ...
# 4137  ab97dea1-f362-434f-9ae6-516f0b665afb          ...
# 4299  ad012139-da54-4401-bddf-ec19b5ee1df4          ...
# 2490  aea81fd7-719a-4fcb-8c65-4cca0828492a          ...
# 2662  b087f631-12fc-4397-9fd6-d29e30ed2671          ...
# 1315  b0e3aaa7-3396-4d30-ae96-3a24aae28098          ...
# 3398  b20a7d5e-f00e-47fd-b0b7-e490bd794036          ...
# 4613  b20fe58f-e433-4338-aab7-cfbbbc3ff92a          ...
# 594   b54b8700-fbd7-4572-acf2-3d04dd748b49          ...
# 1247  b581593e-1038-45cf-b9ec-7e1231778484          ...
# 72    b7d234ef-b675-4a9e-8162-1ca16e8e9319          ...
# 1652  b9866f8e-0c72-430a-b924-1afcfb943d2a          ...
# 2452  b9c30041-fbd8-4290-acc7-839fc8ffc3bb          ...
# 203   bb436114-7b54-4184-995a-886ed16471fd          ...
# 2286  bba241b9-27d1-46cd-b441-a5ea9d0d15ac          ...
# 1281  bc7c68ba-3d76-4f12-9c01-7a6dcc6ecfc4          ...
# 2348  bd07f85c-227a-4ed4-83a4-2f6d88dc1dc6          ...
# 427   be29c78c-2ae9-4461-8f14-859d211bee9b          ...
# 4053  be2f09bf-1ea3-40c5-85d7-9160bd3fb215          ...
# 4759  be928c44-4460-4655-ab55-27d07b388c2a          ...
# 124   bf98f50f-471b-460b-b582-e676fb600874          ...
# 2223  bfbaa713-d7e5-4645-8292-12b8c4972edf          ...
# 611   bfd6956e-6c5c-40df-8313-4eabbecc0bf5          ...
# 279   c0b3ea8e-a51f-4a29-9473-4f1f25539fb4          ...
# 1029  c16bece0-6afb-462c-88c5-4c8adfe41e76          ...
# 5098  c2b4ade0-3b38-46ca-a48b-33382b9578c4          ...
# 2506  c2e1d304-f925-4a61-a5b0-82e78584e3e7          ...
# 77    c3df4a99-4c1d-4c6f-a7cb-25937f0ea5ac          ...
# 1919  c526be19-d657-4d43-ab2b-534080aa406b          ...
# 3794  c534f947-7d1e-408d-9dda-5a01ce3423ea          ...
# 3260  c62b057a-f128-45bf-9245-315b03dc1c76          ...
# 4477  c7c84373-9b8f-4b8a-957f-276d9c6d1fba          ...
# 1626  c83dae04-159c-487c-b63d-003f6ba0d776          ...
# 1505  c972873d-b1d6-4416-896a-e57baaa5ab70          ...
# 4644  cc6c2f35-9a13-4098-903a-73d7ad0dc7d9          ...
# 555   cca29980-c1af-4167-9512-6c959eabb62e          ...
# 1988  cdba9de4-714a-4469-bf3e-2e73007587d6          ...
# 397   cdf6ba27-c14c-4cf3-bad2-8b62d293b2ed          ...
# 1011  cdf7b01f-539d-4587-805e-c92d3ece16f2          ...
# 4142  cf91e3b7-fc6c-4e0a-b954-4e0be8528e17          ...
# 3336  cfff2cd0-59e4-4b45-8ae3-8b221ed900a8          ...
# 3453  d0c9ba49-16ca-4f05-9de4-7d08ab2d37e4          ...
# 2567  d28f3ffd-e205-405b-9474-74ba1b27e6c6          ...
# 4107  d5998292-ada1-46da-b0e1-d0505ca22297          ...
# 2288  d69f4609-74cb-4986-b08d-517eab85b0fd          ...
# 52    da5d727b-fc21-462e-bcdd-c0a289b4734e          ...
# 81    da7d5f54-3107-40d9-ad56-4c63f6257a48          ...
# 2778  dd46f4f7-0930-4974-853b-a1b3eabd32c3          ...
# 2758  de228776-571b-4374-a813-0498e0334011          ...
# 2455  de9da1de-ce49-4b65-a988-1930570c7700          ...
# 5301  dea186a0-9628-4b3b-8665-5b03624bc025          ...
# 4445  dfd9e18d-d55a-4809-ae68-c188728dc810          ...
# 35    e0c7db94-f9ff-4490-8672-b796a90983ac          ...
# 2805  e3a979a9-3494-4bf8-a54b-e5c4a1c179aa          ...
# 1086  e3b25054-3927-4f58-bff0-67d961de61ec          ...
# 522   e508a5d1-694c-4027-b692-c9efeeaf4e9d          ...
# 2705  e62b123f-177e-460d-97d1-96da1adeb99f          ...
# 928   e64f173b-f964-4a59-bb9f-6b57ac60a050          ...
# 750   e700ace7-de45-4643-af49-d3c06fea67eb          ...
# 4088  e75996f8-5bd1-47cc-82fa-2ad4fd547dcb          ...
# 4734  e75bad28-cf83-4f27-99dd-4362095d0efe          ...
# 1586  e8b6b567-5cbe-42b8-9531-1eaf362f9401          ...
# 648   e9be8ed0-f9d0-4af0-8a41-b93eceb2fc05          ...
# 969   eb235e7a-aa04-4dc2-a458-08ce08fe98db          ...
# 2804  ec6759fa-bb83-4694-a5e0-4e369c005906          ...
# 242   ed619c2a-0168-49e0-9b16-5ab6c69287b9          ...
# 1123  eed9272c-893c-41be-a3a7-bdcabea304b0          ...
# 3306  ef6510f1-7866-40c0-8a54-d21751d59af9          ...
# 710   f02b76c4-63fe-4902-8fb2-9c7412028b6d          ...
# 660   f10ac1bd-fe5b-4ce0-9f12-132abfd6115e          ...
# 1790  f11bba25-7e0e-4aea-9156-dc0a77416aa9          ...
# 2037  f1f05182-9802-432f-b8a0-494121af21f8          ...
# 2116  f4573061-9af4-4792-89f8-4e6c14e967c0          ...
# 1217  f4da23aa-6fa7-4920-97d4-112908d8bd54          ...
# 3230  f59169d5-5fbd-4501-bfec-fac6b29e7039          ...
# 851   f5a930a6-a74b-46cb-9c37-1f7716a7695e          ...
# 4642  f6eec93e-16d0-48d1-a5df-72dd5d499338          ...
# 2993  f98dcc6f-8a25-482b-823d-06732fa62e3b          ...
# 830   fa37a41b-2567-41c8-b04a-30782cf838e8          ...
# 2649  faf398e3-ee42-4548-940a-a52fe0ca6155          ...
# 4000  fb595bf8-60c7-4c98-be58-0a1fed616f8c          ...
# 2717  fbd9b8e2-14c5-4aba-88e5-f70ea3d4fa15          ...
# 3167  fde6d992-e7d3-4048-bce8-74e65b60e975          ...
# 566   fe18cdff-c52a-438d-8b49-920bd5c55af7          ...
# 4933  fe2a33aa-6566-44b0-90ad-8f703cc55091          ...
# 3142  fe344ddc-c27a-477c-a734-b2de8963d991          ...
# 3438  ffc47dd4-581c-441a-b255-39b0c5d2dbf8          ...
# 4279  ffd31cde-3fca-4623-9ea6-d583fbbb396a          ...
# 78    ffe6cf3a-2f3a-4ab9-8bac-1ba230a374c9          ...
#
#                page_urlhost dvce_created_tstamp           referral_url  rank
# 2776  snowplowanalytics.com 2021-02-14 00:18:00  snowplowanalytics.com  1.00
# 4052  snowplowanalytics.com 2021-12-02 08:09:00  snowplowanalytics.com  1.00
# 1372  snowplowanalytics.com 2021-02-14 03:08:00  snowplowanalytics.com  1.00
# 3377  snowplowanalytics.com 2021-12-02 10:46:00  snowplowanalytics.com  1.00
# 4854  snowplowanalytics.com 2021-02-13 14:27:00  snowplowanalytics.com  1.00
# 2639  snowplowanalytics.com 2021-12-02 12:06:00  snowplowanalytics.com  1.00
# 1749  snowplowanalytics.com 2021-11-02 11:57:00  snowplowanalytics.com  1.00
# 712   snowplowanalytics.com 2021-11-02 09:05:00  snowplowanalytics.com  1.00
# 3194  snowplowanalytics.com 2021-12-02 16:00:00  snowplowanalytics.com  1.00
# 2213  snowplowanalytics.com 2021-12-02 06:52:00  snowplowanalytics.com  1.00
# 1871  snowplowanalytics.com 2021-12-02 23:14:00  snowplowanalytics.com  1.00
# 4302  snowplowanalytics.com 2021-02-13 22:46:00  snowplowanalytics.com  1.00
# 4767  snowplowanalytics.com 2021-12-02 10:40:00  snowplowanalytics.com  1.00
# 5281  snowplowanalytics.com 2021-12-02 17:08:00  snowplowanalytics.com  1.00
# 4945  snowplowanalytics.com 2021-02-14 16:16:00  snowplowanalytics.com  1.00
# 4426  snowplowanalytics.com 2021-11-02 04:46:00  snowplowanalytics.com  1.00
# 2749  snowplowanalytics.com 2021-02-13 23:58:00  snowplowanalytics.com  1.00
# 1364  snowplowanalytics.com 2021-02-13 21:43:00  snowplowanalytics.com  1.00
# 4260  snowplowanalytics.com 2021-02-13 00:44:00  snowplowanalytics.com  1.00
# 1101  snowplowanalytics.com 2021-12-02 06:00:00  snowplowanalytics.com  1.00
# 34    snowplowanalytics.com 2021-11-02 15:22:00  snowplowanalytics.com  1.00
# 2135  snowplowanalytics.com 2021-12-02 19:39:00  snowplowanalytics.com  1.00
# 60    snowplowanalytics.com 2021-11-02 23:44:00  snowplowanalytics.com  1.00
# 2436  snowplowanalytics.com 2021-02-13 16:50:00  snowplowanalytics.com  1.00
# 635   snowplowanalytics.com 2021-12-02 15:03:00  snowplowanalytics.com  1.00
# 2049  snowplowanalytics.com 2021-12-02 10:36:00  snowplowanalytics.com  1.00
# 4707  snowplowanalytics.com 2021-12-02 05:02:00  snowplowanalytics.com  1.00
# 2398  snowplowanalytics.com 2021-02-14 00:23:00  snowplowanalytics.com  1.00
# 1184  snowplowanalytics.com 2021-02-13 23:08:00  snowplowanalytics.com  1.00
# 3132  snowplowanalytics.com 2021-11-02 12:20:00  snowplowanalytics.com  1.00
# 4877  snowplowanalytics.com 2021-02-13 19:51:00  snowplowanalytics.com  1.00
# 106   snowplowanalytics.com 2021-02-13 00:25:00  snowplowanalytics.com  1.00
# 5276  snowplowanalytics.com 2021-12-02 16:30:00  snowplowanalytics.com  1.00
# 3062  snowplowanalytics.com 2021-02-13 14:57:00  snowplowanalytics.com  1.00
# 772   snowplowanalytics.com 2021-12-02 09:50:00  snowplowanalytics.com  1.00
# 2706  snowplowanalytics.com 2021-02-13 12:40:00  snowplowanalytics.com  1.00
# 3585  snowplowanalytics.com 2021-02-13 12:28:00  snowplowanalytics.com  1.00
# 4059  snowplowanalytics.com 2021-12-02 10:24:00  snowplowanalytics.com  1.00
# 5319  snowplowanalytics.com 2021-02-13 09:43:00  snowplowanalytics.com  1.00
# 2035  snowplowanalytics.com 2021-12-02 01:20:00  snowplowanalytics.com  1.00
# 2311  snowplowanalytics.com 2021-02-14 04:17:00  snowplowanalytics.com  1.00
# 3999  snowplowanalytics.com 2021-11-02 08:16:00  snowplowanalytics.com  1.00
# 5449  snowplowanalytics.com 2021-12-02 06:36:00  snowplowanalytics.com  1.00
# 3402  snowplowanalytics.com 2021-12-02 20:32:00  snowplowanalytics.com  1.00
# 630   snowplowanalytics.com 2021-12-02 13:43:00  snowplowanalytics.com  1.00
# 1326  snowplowanalytics.com 2021-12-02 20:23:00  snowplowanalytics.com  1.00
# 1703  snowplowanalytics.com 2021-12-02 22:19:00  snowplowanalytics.com  1.00
# 2143  snowplowanalytics.com 2021-11-02 12:10:00  snowplowanalytics.com  1.00
# 1381  snowplowanalytics.com 2021-02-14 09:36:00  snowplowanalytics.com  1.00
# 3101  snowplowanalytics.com 2021-02-14 05:15:00  snowplowanalytics.com  1.00
# 507   snowplowanalytics.com 2021-02-13 16:59:00  snowplowanalytics.com  1.00
# 1531  snowplowanalytics.com 2021-11-02 16:10:00  snowplowanalytics.com  1.00
# 2916  snowplowanalytics.com 2021-12-02 10:25:00  snowplowanalytics.com  1.00
# 1329  snowplowanalytics.com 2021-12-02 21:52:00  snowplowanalytics.com  1.00
# 4100  snowplowanalytics.com 2021-02-13 05:35:00  snowplowanalytics.com  1.00
# 3694  snowplowanalytics.com 2021-12-02 09:27:00  snowplowanalytics.com  1.00
# 1697  snowplowanalytics.com 2021-12-02 21:10:00  snowplowanalytics.com  1.00
# 3665  snowplowanalytics.com 2021-11-02 17:46:00  snowplowanalytics.com  1.00
# 267   snowplowanalytics.com 2021-12-02 15:38:00  snowplowanalytics.com  1.00
# 4456  snowplowanalytics.com 2021-02-13 10:28:00  snowplowanalytics.com  1.00
# 2294  snowplowanalytics.com 2021-02-13 14:38:00  snowplowanalytics.com  1.00
# 1158  snowplowanalytics.com 2021-02-13 09:14:00  snowplowanalytics.com  1.00
# 4522  snowplowanalytics.com 2021-11-02 08:29:00  snowplowanalytics.com  1.00
# 1306  snowplowanalytics.com 2021-12-02 12:31:00  snowplowanalytics.com  1.00
# 325   snowplowanalytics.com 2021-02-13 16:19:00  snowplowanalytics.com  1.00
# 1083  snowplowanalytics.com 2021-11-02 22:43:00  snowplowanalytics.com  1.00
# 1604  snowplowanalytics.com 2021-02-13 02:49:00  snowplowanalytics.com  1.00
# 1209  snowplowanalytics.com 2021-02-14 01:51:00  snowplowanalytics.com  1.00
# 4980  snowplowanalytics.com 2021-02-13 18:47:00  snowplowanalytics.com  1.00
# 3960  snowplowanalytics.com 2021-02-13 23:43:00  snowplowanalytics.com  1.00
# 4986  snowplowanalytics.com 2021-02-13 21:05:00  snowplowanalytics.com  1.00
# 1563  snowplowanalytics.com 2021-12-02 09:36:00  snowplowanalytics.com  1.00
# 3536  snowplowanalytics.com 2021-12-02 11:03:00  snowplowanalytics.com  1.00
# 2225  snowplowanalytics.com 2021-12-02 11:04:00  snowplowanalytics.com  1.00
# 3116  snowplowanalytics.com 2021-02-14 08:54:00  snowplowanalytics.com  1.00
# 530   snowplowanalytics.com 2021-02-14 13:40:00  snowplowanalytics.com  1.00
# 1321  snowplowanalytics.com 2021-12-02 18:51:00  snowplowanalytics.com  1.00
# 3777  snowplowanalytics.com 2021-02-14 00:31:00  snowplowanalytics.com  1.00
# 837   snowplowanalytics.com 2021-12-02 23:26:00  snowplowanalytics.com  1.00
# 1206  snowplowanalytics.com 2021-02-13 23:23:00  snowplowanalytics.com  1.00
# 321   snowplowanalytics.com 2021-02-13 15:22:00  snowplowanalytics.com  1.00
# 156   snowplowanalytics.com 2021-02-13 21:15:00  snowplowanalytics.com  1.00
# 1412  snowplowanalytics.com 2021-11-02 10:24:00  snowplowanalytics.com  1.00
# 1375  snowplowanalytics.com 2021-02-14 06:58:00  snowplowanalytics.com  1.00
# 1396  snowplowanalytics.com 2021-02-14 20:33:00  snowplowanalytics.com  1.00
# 852   snowplowanalytics.com 2021-02-13 05:12:00  snowplowanalytics.com  1.00
# 1610  snowplowanalytics.com 2021-02-13 04:07:00  snowplowanalytics.com  1.00
# 1841  snowplowanalytics.com 2021-02-13 19:35:00  snowplowanalytics.com  1.00
# 569   snowplowanalytics.com 2021-11-02 09:48:00  snowplowanalytics.com  1.00
# 886   snowplowanalytics.com 2021-12-02 17:55:00  snowplowanalytics.com  1.00
# 486   snowplowanalytics.com 2021-02-13 09:31:00  snowplowanalytics.com  1.00
# 1226  snowplowanalytics.com 2021-11-02 00:52:00  snowplowanalytics.com  1.00
# 662   snowplowanalytics.com 2021-02-13 02:30:00  snowplowanalytics.com  1.00
# 341   snowplowanalytics.com 2021-02-13 22:54:00  snowplowanalytics.com  1.00
# 865   snowplowanalytics.com 2021-02-13 13:08:00  snowplowanalytics.com  1.00
# 1917  snowplowanalytics.com 2021-02-13 18:34:00  snowplowanalytics.com  1.00
# 2459  snowplowanalytics.com 2021-02-14 17:57:00  snowplowanalytics.com  1.00
# 4720  snowplowanalytics.com 2021-12-02 06:07:00  snowplowanalytics.com  1.00
# 939   snowplowanalytics.com 2021-02-14 16:45:00  snowplowanalytics.com  1.00
# 3991  snowplowanalytics.com 2021-11-02 04:53:00  snowplowanalytics.com  1.00
# 2204  snowplowanalytics.com 2021-12-02 00:48:00  snowplowanalytics.com  1.00
# 468   snowplowanalytics.com 2021-12-02 21:07:00  snowplowanalytics.com  1.00
# 225   snowplowanalytics.com 2021-11-02 21:15:00  snowplowanalytics.com  1.00
# 485   snowplowanalytics.com 2021-02-13 09:27:00  snowplowanalytics.com  1.00
# 1709  snowplowanalytics.com 2021-02-13 03:52:00  snowplowanalytics.com  1.00
# 2132  snowplowanalytics.com 2021-12-02 18:33:00  snowplowanalytics.com  1.00
# 374   snowplowanalytics.com 2021-11-02 01:31:00  snowplowanalytics.com  1.00
# 1698  snowplowanalytics.com 2021-12-02 21:45:00  snowplowanalytics.com  1.00
# 4972  snowplowanalytics.com 2021-02-13 15:07:00  snowplowanalytics.com  1.00
# 3162  snowplowanalytics.com 2021-11-02 21:04:00  snowplowanalytics.com  1.00
# 3904  snowplowanalytics.com 2021-12-02 20:13:00  snowplowanalytics.com  1.00
# 730   snowplowanalytics.com 2021-11-02 17:37:00  snowplowanalytics.com  1.00
# 4965  snowplowanalytics.com 2021-02-13 12:49:00  snowplowanalytics.com  1.00
# 680   snowplowanalytics.com 2021-11-02 06:17:00  snowplowanalytics.com  1.00
# 2263  snowplowanalytics.com 2021-02-13 01:25:00  snowplowanalytics.com  1.00
# 893   snowplowanalytics.com 2021-12-02 21:17:00  snowplowanalytics.com  1.00
# 781   snowplowanalytics.com 2021-12-02 11:53:00  snowplowanalytics.com  1.00
# 205   snowplowanalytics.com 2021-11-02 13:03:00  snowplowanalytics.com  1.00
# 2388  snowplowanalytics.com 2021-02-13 18:27:00  snowplowanalytics.com  1.00
# 2478  snowplowanalytics.com 2021-11-02 02:29:00  snowplowanalytics.com  1.00
# 973   snowplowanalytics.com 2021-02-14 01:16:00  snowplowanalytics.com  1.00
# 622   snowplowanalytics.com 2021-12-02 12:08:00  snowplowanalytics.com  1.00
# 912   snowplowanalytics.com 2021-02-13 01:40:00  snowplowanalytics.com  1.00
# 1047  snowplowanalytics.com 2021-11-02 12:31:00  snowplowanalytics.com  1.00
# 3620  snowplowanalytics.com 2021-02-14 13:40:00  snowplowanalytics.com  1.00
# 1304  snowplowanalytics.com 2021-12-02 10:52:00  snowplowanalytics.com  1.00
# 2437  snowplowanalytics.com 2021-02-13 16:55:00  snowplowanalytics.com  1.00
# 4213  snowplowanalytics.com 2021-12-02 01:26:00  snowplowanalytics.com  1.00
# 2361  snowplowanalytics.com 2021-02-13 01:33:00  snowplowanalytics.com  1.00
# 2669  snowplowanalytics.com 2021-12-02 16:09:00  snowplowanalytics.com  1.00
# 2333  snowplowanalytics.com 2021-12-02 14:44:00  snowplowanalytics.com  1.00
# 2103  snowplowanalytics.com 2021-12-02 14:22:00  snowplowanalytics.com  1.00
# 230   snowplowanalytics.com 2021-11-02 23:59:00  snowplowanalytics.com  1.00
# 1073  snowplowanalytics.com 2021-11-02 18:57:00  snowplowanalytics.com  1.00
# 754   snowplowanalytics.com 2021-11-02 23:29:00  snowplowanalytics.com  1.00
# 3593  snowplowanalytics.com 2021-02-13 16:28:00  snowplowanalytics.com  1.00
# 4133  snowplowanalytics.com 2021-02-13 21:29:00  snowplowanalytics.com  1.00
# 1930  snowplowanalytics.com 2021-02-14 22:21:00  snowplowanalytics.com  1.00
# 21    snowplowanalytics.com 2021-11-02 11:54:00  snowplowanalytics.com  1.00
# 1641  snowplowanalytics.com 2021-02-13 16:44:00  snowplowanalytics.com  1.00
# 1866  snowplowanalytics.com 2021-12-02 20:50:00  snowplowanalytics.com  1.00
# 766   snowplowanalytics.com 2021-12-02 08:16:00  snowplowanalytics.com  1.00
# 49    snowplowanalytics.com 2021-11-02 19:40:00  snowplowanalytics.com  1.00
# 1325  snowplowanalytics.com 2021-12-02 19:58:00  snowplowanalytics.com  1.00
# 1651  snowplowanalytics.com 2021-02-13 21:31:00  snowplowanalytics.com  1.00
# 1084  snowplowanalytics.com 2021-11-02 23:02:00  snowplowanalytics.com  1.00
# 1193  snowplowanalytics.com 2021-02-14 13:46:00  snowplowanalytics.com  1.00
# 1852  snowplowanalytics.com 2021-12-02 15:36:00  snowplowanalytics.com  1.00
# 5107  snowplowanalytics.com 2021-11-02 13:00:00  snowplowanalytics.com  1.00
# 452   snowplowanalytics.com 2021-12-02 12:09:00  snowplowanalytics.com  1.00
# 5512  snowplowanalytics.com 2021-02-13 11:26:00  snowplowanalytics.com  1.00
# 295   snowplowanalytics.com 2021-02-13 05:47:00  snowplowanalytics.com  1.00
# 1516  snowplowanalytics.com 2021-11-02 10:42:00  snowplowanalytics.com  1.00
# 3031  snowplowanalytics.com 2021-02-13 06:43:00  snowplowanalytics.com  1.00
# 1780  snowplowanalytics.com 2021-02-13 14:23:00  snowplowanalytics.com  1.00
# 2730  snowplowanalytics.com 2021-02-13 17:27:00  snowplowanalytics.com  1.00
# 2482  snowplowanalytics.com 2021-11-02 06:31:00  snowplowanalytics.com  1.00
# 1689  snowplowanalytics.com 2021-02-14 15:01:00  snowplowanalytics.com  1.00
# 2990  snowplowanalytics.com 2021-12-02 17:51:00  snowplowanalytics.com  1.00
# 1900  snowplowanalytics.com 2021-02-13 10:19:00  snowplowanalytics.com  1.00
# 810   snowplowanalytics.com 2021-11-02 20:04:00  snowplowanalytics.com  1.00
# 457   snowplowanalytics.com 2021-12-02 15:13:00  snowplowanalytics.com  1.00
# 2773  snowplowanalytics.com 2021-02-13 23:13:00  snowplowanalytics.com  1.00
# 1696  snowplowanalytics.com 2021-02-14 20:06:00  snowplowanalytics.com  1.00
# 560   snowplowanalytics.com 2021-11-02 05:36:00  snowplowanalytics.com  1.00
# 992   snowplowanalytics.com 2021-02-14 18:19:00  snowplowanalytics.com  1.00
# 2893  snowplowanalytics.com 2021-12-02 06:15:00  snowplowanalytics.com  1.00
# 736   snowplowanalytics.com 2021-11-02 14:57:00  snowplowanalytics.com  1.00
# 5546  snowplowanalytics.com 2021-02-14 07:34:00  snowplowanalytics.com  1.00
# 3811  snowplowanalytics.com 2021-11-02 04:15:00  snowplowanalytics.com  1.00
# 770   snowplowanalytics.com 2021-12-02 09:05:00  snowplowanalytics.com  1.00
# 1330  snowplowanalytics.com 2021-12-02 22:09:00  snowplowanalytics.com  1.00
# 101   snowplowanalytics.com 2021-12-02 22:20:00  snowplowanalytics.com  1.00
# 74    snowplowanalytics.com 2021-12-02 12:51:00  snowplowanalytics.com  1.00
# 3207  snowplowanalytics.com 2021-12-02 22:18:00  snowplowanalytics.com  1.00
# 785   snowplowanalytics.com 2021-12-02 13:26:00  snowplowanalytics.com  1.00
# 2630  snowplowanalytics.com 2021-12-02 16:03:00  snowplowanalytics.com  1.00
# 2448  snowplowanalytics.com 2021-02-13 23:13:00  snowplowanalytics.com  1.00
# 3374  snowplowanalytics.com 2021-12-02 09:54:00  snowplowanalytics.com  1.00
# 3166  snowplowanalytics.com 2021-11-02 23:56:00  snowplowanalytics.com  1.00
# 3775  snowplowanalytics.com 2021-02-13 23:42:00  snowplowanalytics.com  1.00
# 3660  snowplowanalytics.com 2021-11-02 16:52:00  snowplowanalytics.com  1.00
# 346   snowplowanalytics.com 2021-02-14 00:55:00  snowplowanalytics.com  1.00
# 4578  snowplowanalytics.com 2021-11-02 02:20:00  snowplowanalytics.com  1.00
# 4119  snowplowanalytics.com 2021-02-13 13:42:00  snowplowanalytics.com  1.00
# 1324  snowplowanalytics.com 2021-12-02 19:48:00  snowplowanalytics.com  1.00
# 4340  snowplowanalytics.com 2021-11-02 06:00:00  snowplowanalytics.com  1.00
# 1389  snowplowanalytics.com 2021-02-14 15:47:00  snowplowanalytics.com  1.00
# 4137  snowplowanalytics.com 2021-02-13 23:13:00  snowplowanalytics.com  1.00
# 4299  snowplowanalytics.com 2021-02-13 21:23:00  snowplowanalytics.com  1.00
# 2490  snowplowanalytics.com 2021-09-02 08:55:00  snowplowanalytics.com  1.00
# 2662  snowplowanalytics.com 2021-12-02 14:51:00  snowplowanalytics.com  1.00
# 1315  snowplowanalytics.com 2021-12-02 16:03:00  snowplowanalytics.com  1.00
# 3398  snowplowanalytics.com 2021-12-02 19:02:00  snowplowanalytics.com  1.00
# 4613  snowplowanalytics.com 2021-11-02 12:35:00  snowplowanalytics.com  1.00
# 594   snowplowanalytics.com 2021-11-02 17:12:00  snowplowanalytics.com  1.00
# 1247  snowplowanalytics.com 2021-11-02 11:50:00  snowplowanalytics.com  1.00
# 72    snowplowanalytics.com 2021-12-02 10:59:00  snowplowanalytics.com  1.00
# 1652  snowplowanalytics.com 2021-12-02 12:48:00  snowplowanalytics.com  1.00
# 2452  snowplowanalytics.com 2021-02-14 08:04:00  snowplowanalytics.com  1.00
# 203   snowplowanalytics.com 2021-11-02 12:08:00  snowplowanalytics.com  1.00
# 2286  snowplowanalytics.com 2021-02-13 12:30:00  snowplowanalytics.com  1.00
# 1281  snowplowanalytics.com 2021-11-02 22:26:00  snowplowanalytics.com  1.00
# 2348  snowplowanalytics.com 2021-12-02 20:20:00  snowplowanalytics.com  1.00
# 427   snowplowanalytics.com 2021-12-02 00:48:00  snowplowanalytics.com  1.00
# 4053  snowplowanalytics.com 2021-12-02 08:50:00  snowplowanalytics.com  1.00
# 4759  snowplowanalytics.com 2021-12-02 14:29:00  snowplowanalytics.com  1.00
# 124   snowplowanalytics.com 2021-02-13 10:05:00  snowplowanalytics.com  1.00
# 2223  snowplowanalytics.com 2021-12-02 09:34:00  snowplowanalytics.com  1.00
# 611   snowplowanalytics.com 2021-12-02 05:01:00  snowplowanalytics.com  1.00
# 279   snowplowanalytics.com 2021-12-02 20:54:00  snowplowanalytics.com  1.00
# 1029  snowplowanalytics.com 2021-02-13 11:25:00  snowplowanalytics.com  1.00
# 5098  snowplowanalytics.com 2021-10-02 11:55:00  snowplowanalytics.com  1.00
# 2506  snowplowanalytics.com 2021-11-02 17:33:00  snowplowanalytics.com  1.00
# 77    snowplowanalytics.com 2021-12-02 13:40:00  snowplowanalytics.com  1.00
# 1919  snowplowanalytics.com 2021-02-13 19:38:00  snowplowanalytics.com  1.00
# 3794  snowplowanalytics.com 2021-02-14 15:39:00  snowplowanalytics.com  1.00
# 3260  snowplowanalytics.com 2021-02-13 22:22:00  snowplowanalytics.com  1.00
# 4477  snowplowanalytics.com 2021-02-13 17:52:00  snowplowanalytics.com  1.00
# 1626  snowplowanalytics.com 2021-02-13 11:21:00  snowplowanalytics.com  1.00
# 1505  snowplowanalytics.com 2021-11-02 07:58:00  snowplowanalytics.com  1.00
# 4644  snowplowanalytics.com 2021-12-02 08:31:00  snowplowanalytics.com  1.00
# 555   snowplowanalytics.com 2021-11-02 04:06:00  snowplowanalytics.com  1.00
# 1988  snowplowanalytics.com 2021-11-02 02:53:00  snowplowanalytics.com  1.00
# 397   snowplowanalytics.com 2021-11-02 12:31:00  snowplowanalytics.com  1.00
# 1011  snowplowanalytics.com 2021-02-13 07:41:00  snowplowanalytics.com  1.00
# 4142  snowplowanalytics.com 2021-02-14 02:02:00  snowplowanalytics.com  1.00
# 3336  snowplowanalytics.com 2021-11-02 18:18:00  snowplowanalytics.com  1.00
# 3453  snowplowanalytics.com 2021-02-14 20:03:00  snowplowanalytics.com  1.00
# 2567  snowplowanalytics.com 2021-12-02 00:47:00  snowplowanalytics.com  1.00
# 4107  snowplowanalytics.com 2021-02-13 08:16:00  snowplowanalytics.com  1.00
# 2288  snowplowanalytics.com 2021-02-13 13:18:00  snowplowanalytics.com  1.00
# 52    snowplowanalytics.com 2021-11-02 20:00:00  snowplowanalytics.com  1.00
# 81    snowplowanalytics.com 2021-12-02 14:57:00  snowplowanalytics.com  1.00
# 2778  snowplowanalytics.com 2021-02-14 01:33:00  snowplowanalytics.com  1.00
# 2758  snowplowanalytics.com 2021-02-14 05:26:00  snowplowanalytics.com  1.00
# 2455  snowplowanalytics.com 2021-02-14 14:04:00  snowplowanalytics.com  1.00
# 5301  snowplowanalytics.com 2021-02-13 02:03:00  snowplowanalytics.com  1.00
# 4445  snowplowanalytics.com 2021-02-13 05:17:00  snowplowanalytics.com  1.00
# 35    snowplowanalytics.com 2021-11-02 15:59:00  snowplowanalytics.com  1.00
# 2805  snowplowanalytics.com 2021-11-02 02:16:00  snowplowanalytics.com  1.00
# 1086  snowplowanalytics.com 2021-12-02 00:10:00  snowplowanalytics.com  1.00
# 522   snowplowanalytics.com 2021-02-14 10:39:00  snowplowanalytics.com  1.00
# 2705  snowplowanalytics.com 2021-02-13 12:11:00  snowplowanalytics.com  1.00
# 928   snowplowanalytics.com 2021-02-13 11:43:00  snowplowanalytics.com  1.00
# 750   snowplowanalytics.com 2021-11-02 22:02:00  snowplowanalytics.com  1.00
# 4088  snowplowanalytics.com 2021-12-02 20:41:00  snowplowanalytics.com  1.00
# 4734  snowplowanalytics.com 2021-12-02 09:00:00  snowplowanalytics.com  1.00
# 1586  snowplowanalytics.com 2021-12-02 18:10:00  snowplowanalytics.com  1.00
# 648   snowplowanalytics.com 2021-12-02 19:40:00  snowplowanalytics.com  1.00
# 969   snowplowanalytics.com 2021-02-13 23:13:00  snowplowanalytics.com  1.00
# 2804  snowplowanalytics.com 2021-11-02 01:37:00  snowplowanalytics.com  1.00
# 242   snowplowanalytics.com 2021-12-02 08:19:00  snowplowanalytics.com  1.00
# 1123  snowplowanalytics.com 2021-12-02 14:53:00  snowplowanalytics.com  1.00
# 3306  snowplowanalytics.com 2021-11-02 09:49:00  snowplowanalytics.com  1.00
# 710   snowplowanalytics.com 2021-11-02 08:33:00  snowplowanalytics.com  1.00
# 660   snowplowanalytics.com 2021-02-13 00:07:00  snowplowanalytics.com  1.00
# 1790  snowplowanalytics.com 2021-02-13 16:02:00  snowplowanalytics.com  1.00
# 2037  snowplowanalytics.com 2021-12-02 02:37:00  snowplowanalytics.com  1.00
# 2116  snowplowanalytics.com 2021-11-02 04:02:00  snowplowanalytics.com  1.00
# 1217  snowplowanalytics.com 2021-02-14 14:34:00  snowplowanalytics.com  1.00
# 3230  snowplowanalytics.com 2021-02-13 07:57:00  snowplowanalytics.com  1.00
# 851   snowplowanalytics.com 2021-02-13 05:00:00  snowplowanalytics.com  1.00
# 4642  snowplowanalytics.com 2021-12-02 08:00:00  snowplowanalytics.com  1.00
# 2993  snowplowanalytics.com 2021-12-02 18:38:00  snowplowanalytics.com  1.00
# 830   snowplowanalytics.com 2021-12-02 21:23:00  snowplowanalytics.com  1.00
# 2649  snowplowanalytics.com 2021-02-13 01:12:00  snowplowanalytics.com  1.00
# 4000  snowplowanalytics.com 2021-11-02 08:26:00  snowplowanalytics.com  1.00
# 2717  snowplowanalytics.com 2021-02-13 16:31:00  snowplowanalytics.com  1.00
# 3167  snowplowanalytics.com 2021-11-02 23:57:00  snowplowanalytics.com  1.00
# 566   snowplowanalytics.com 2021-11-02 06:47:00  snowplowanalytics.com  1.00
# 4933  snowplowanalytics.com 2021-02-14 03:35:00  snowplowanalytics.com  1.00
# 3142  snowplowanalytics.com 2021-11-02 14:14:00  snowplowanalytics.com  1.00
# 3438  snowplowanalytics.com 2021-02-13 21:28:00  snowplowanalytics.com  1.00
# 4279  snowplowanalytics.com 2021-02-13 11:42:00  snowplowanalytics.com  1.00
# 78    snowplowanalytics.com 2021-12-02 14:11:00  snowplowanalytics.com  1.00

# %%
# Create a table with all users going to with discourse.snowplowanalytics.com as second page_view
df_table2 = df_temp.loc[(df_temp['page_urlhost']=='discourse.snowplowanalytics.com')&(df_temp['rank']==2)]
# join both tables to find users starting on snowplowanalytics.com and then going to discourse.snowplowanalytics.com
df_merge = pd.merge(dfff1, dfff2, on=["session_id"])
# count distinct on session_id
numerator = len(df_merge)
len(df_merge)
# Out:
# 20

# %%
percent_users_o2 = numerator/denominator
print(f'Distinct users starting on Snowplowanalytics: {denominator}')
print(f'Distinct users starting on Snowplowanalytics and continuing to Discourse: {numerator}')
print(f'Percentage of users is: {percent_users_o2:.2%}')
# Out:
# Distinct users starting on Snowplowanalytics: 2144
# Distinct users starting on Snowplowanalytics and continuing to Discourse: 20
# Percentage of users is: 0.93%

# %% [markdown]
# # Data analysis & modelling - Section 3
#
# 3. Imagine you intend to use this dataset for repeated analysis in the future, describe what transformations you would perform on the dataset to derive a set of views that contain analytics ready data. You do not need to write code defining your view(s).
#
#    * I would include a <b>page_view_rank</b>. Simply ranking page_view in order of time appearance for each session on a given day. To calculate the Bounce Rate, I would simply need to count user with a max page_view_rank of 1.<br><br>
#
#    * A page_view_rank can also be useful to recreate the full user journey by pivoting the ranks in columns containing the name of each page_view e.g. imagine a table with column= rank_1, value= snowplowanalytics.com. Essentially creating the customer journey on the website. It could help to follow patterns like: What % of users start their journey on page_urlhost ='snowplowanalytics.com' before navigating to page_urlhost='discourse.snowplowanalytics.com'. However, dvce_created_tstamp should include seconds to differentiate hits happening on same minute.<br><br>
#
#    * I would also include a <b>session_duration</b> field. Essentially, tracking the duration of each active page view. It should be doable as a page_ping is sent at a regular cadence. The session_duration would make it much easier to compute the average time on a page.<br><br>
#
#    * Similarly, I would also include a <b>scroll_depth</b> derived from the raw data.<br><br>
#
#    * All the suggestions above aim to create metrics. They can be part of the raw data itself or can form a first aggregation table. A second aggregation layer could be to group metrics like session_duration or scroll_depth into buckets e.g. scroll_depth 25%, 50%, 75% and 100%.<br><br>
#
#    * Part of this second aggregation layer, I would create a series of time entities derived from dvce_created_tstamp, such: Date (dd/mm/yyyy), Week, Month, Quarter, Year. It would be then much easier to aggregate any metric according to specific date dimensions and follow their evolution through time e.g. MoM, YoY.<br><br>
